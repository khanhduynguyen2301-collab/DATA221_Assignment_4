# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# 2) Normalize pixel values to [0, 1]
X_train = X_train / 255.0
X_test = X_test / 255.0

# 3) Reshape images to include the channel dimension
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# 4) Build the CNN model
cnn_model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# 5) Compile the model
cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 6) Train the model
cnn_model.fit(X_train, y_train, epochs=15, validation_split=0.1)

# 7) Evaluate on test set
test_loss, test_accuracy = cnn_model.evaluate(X_test, y_test)
print("Test accuracy:", test_accuracy)

# CNNs are better for images because they keep spatial information and learn
# local patterns such as edges and shapes, while using fewer parameters than
# fully connected networks.

# In this task, the convolution layer learns visual features like edges, outlines,
# curves, and simple texture patterns that help classify clothing images.
# Out:
# C:\Users\ASUS\PycharmProjects\JupyterProject3\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8486 - loss: 0.4286 - val_accuracy: 0.8852 - val_loss: 0.3182
# Epoch 2/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8968 - loss: 0.2891 - val_accuracy: 0.8935 - val_loss: 0.2909
# Epoch 3/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9096 - loss: 0.2475 - val_accuracy: 0.9007 - val_loss: 0.2717
# Epoch 4/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9204 - loss: 0.2176 - val_accuracy: 0.9055 - val_loss: 0.2582
# Epoch 5/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9286 - loss: 0.1940 - val_accuracy: 0.8942 - val_loss: 0.2883
# Epoch 6/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9386 - loss: 0.1705 - val_accuracy: 0.9083 - val_loss: 0.2536
# Epoch 7/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9443 - loss: 0.1535 - val_accuracy: 0.9012 - val_loss: 0.2874
# Epoch 8/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9490 - loss: 0.1372 - val_accuracy: 0.9062 - val_loss: 0.2771
# Epoch 9/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9540 - loss: 0.1244 - val_accuracy: 0.9037 - val_loss: 0.2991
# Epoch 10/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9592 - loss: 0.1096 - val_accuracy: 0.9137 - val_loss: 0.2836
# Epoch 11/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9639 - loss: 0.0988 - val_accuracy: 0.9120 - val_loss: 0.3016
# Epoch 12/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9676 - loss: 0.0885 - val_accuracy: 0.9128 - val_loss: 0.3150
# Epoch 13/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9712 - loss: 0.0777 - val_accuracy: 0.9117 - val_loss: 0.3236
# Epoch 14/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9745 - loss: 0.0710 - val_accuracy: 0.9055 - val_loss: 0.3511
# Epoch 15/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9775 - loss: 0.0638 - val_accuracy: 0.9065 - val_loss: 0.3676
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9122 - loss: 0.3682
# Test accuracy: 0.9121999740600586
