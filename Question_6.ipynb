# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# 2) Normalize pixel values to [0, 1]
X_train = X_train / 255.0
X_test = X_test / 255.0

# 3) Reshape images to include the channel dimension
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# 4) Build the CNN model
cnn_model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# 5) Compile the model
cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 6) Train the model
cnn_model.fit(X_train, y_train, epochs=15, validation_split=0.1)

# 7) Evaluate on test set
test_loss, test_accuracy = cnn_model.evaluate(X_test, y_test)
print("Test accuracy:", test_accuracy)

# CNNs are better for images because they keep spatial information and learn
# local patterns such as edges and shapes, while using fewer parameters than
# fully connected networks.

# In this task, the convolution layer learns visual features like edges, outlines,
# curves, and simple texture patterns that help classify clothing images.
# Out:
# Epoch 1/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8473 - loss: 0.4319 - val_accuracy: 0.8820 - val_loss: 0.3298
# Epoch 2/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8948 - loss: 0.2944 - val_accuracy: 0.8985 - val_loss: 0.2849
# Epoch 3/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9093 - loss: 0.2515 - val_accuracy: 0.9012 - val_loss: 0.2764
# Epoch 4/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9204 - loss: 0.2208 - val_accuracy: 0.9067 - val_loss: 0.2563
# Epoch 5/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9275 - loss: 0.1973 - val_accuracy: 0.9115 - val_loss: 0.2495
# Epoch 6/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9349 - loss: 0.1754 - val_accuracy: 0.9080 - val_loss: 0.2718
# Epoch 7/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9442 - loss: 0.1555 - val_accuracy: 0.9110 - val_loss: 0.2736
# Epoch 8/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9484 - loss: 0.1397 - val_accuracy: 0.9125 - val_loss: 0.2706
# Epoch 9/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9550 - loss: 0.1232 - val_accuracy: 0.9083 - val_loss: 0.2792
# Epoch 10/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9587 - loss: 0.1107 - val_accuracy: 0.9065 - val_loss: 0.2971
# Epoch 11/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9643 - loss: 0.0993 - val_accuracy: 0.9117 - val_loss: 0.2936
# Epoch 12/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9680 - loss: 0.0867 - val_accuracy: 0.9020 - val_loss: 0.3479
# Epoch 13/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9726 - loss: 0.0768 - val_accuracy: 0.9100 - val_loss: 0.3294
# Epoch 14/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9745 - loss: 0.0700 - val_accuracy: 0.9117 - val_loss: 0.3293
# Epoch 15/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9776 - loss: 0.0615 - val_accuracy: 0.9092 - val_loss: 0.3499
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9094 - loss: 0.3691
# Test accuracy: 0.9093999862670898
