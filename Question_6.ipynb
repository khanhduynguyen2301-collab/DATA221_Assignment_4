# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# 2) Normalize pixel values to [0, 1]
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0

# 3) Reshape images to include the channel dimension
X_train = X_train.reshape([-1, 28, 28, 1])
X_test = X_test.reshape([-1, 28, 28, 1])

# 4) Build the CNN model
cnn_model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# 5) Compile the model
cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 6) Train the model
cnn_model.fit(X_train, y_train, epochs=15, validation_split=0.1)

# 7) Evaluate on test set
test_loss, test_accuracy = cnn_model.evaluate(X_test, y_test)
print("Test accuracy:", test_accuracy)

# CNNs are better for images because they keep spatial information and learn
# local patterns such as edges and shapes, while using fewer parameters than
# fully connected networks.

# In this task, the convolution layer learns visual features like edges, outlines,
# curves, and simple texture patterns that help classify clothing images.
# Out:
# Epoch 1/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8476 - loss: 0.4302 - val_accuracy: 0.8882 - val_loss: 0.3190
# Epoch 2/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8950 - loss: 0.2905 - val_accuracy: 0.9023 - val_loss: 0.2773
# Epoch 3/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9110 - loss: 0.2464 - val_accuracy: 0.9072 - val_loss: 0.2574
# Epoch 4/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9210 - loss: 0.2159 - val_accuracy: 0.9048 - val_loss: 0.2633
# Epoch 5/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9288 - loss: 0.1899 - val_accuracy: 0.9037 - val_loss: 0.2795
# Epoch 6/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9389 - loss: 0.1664 - val_accuracy: 0.9125 - val_loss: 0.2523
# Epoch 7/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9456 - loss: 0.1471 - val_accuracy: 0.9077 - val_loss: 0.2957
# Epoch 8/15
# ...
